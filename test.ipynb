# %% [markdown]
# ## This is my first Text here

# %%
# %load_ext autoreload
# %autoreload 2

# %%
df = spark.table('orders')
display(df)

# %%
# %sql
SELECT * from orders

# %%
from modules.encoder import encode_base64
scope = "prod-ingestion"
key = "opean-weather-default-key"
creds = dbutils.secrets.get(scope=scope, key=key)
print(creds)
print(encode_base64(creds))

# %%
def hello_world(): 
    print("hello world")
